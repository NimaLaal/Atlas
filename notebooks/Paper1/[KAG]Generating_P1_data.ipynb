# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
assert os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] == "false"

import sys
sys.path.append('../')
sys.path.append('../../')

import ATLAS

import json, pickle
from glob import glob
from tqdm import tqdm

import numpy as np
from matplotlib import pyplot as plt

# Make Pint shut up
import pint.logging
import logging
pint.logging.setup(level=logging.WARNING)
logging.getLogger('enterprise').setLevel(logging.WARNING)

from pta_replicator.white_noise import add_measurement_noise, add_jitter
from pta_replicator.red_noise import add_red_noise, add_gwb
from pta_replicator.simulate import make_ideal, load_pulsar

NG15_path = '../../datasets/NG15'
ideal_path = '../../datasets/ideal_NG15'
sim_path = '../../datasets/sim_NG15_01'
# Out:
# JAX 64-bit mode automatically enabled successfully.
# libstempo not installed. PINT or libstempo are required to use par and tim files.

# %%
def get_name(parOrTim):
    return parOrTim.split('/')[-1].split('_')[0]

def get_partim(path):
    parfiles = sorted(glob(f'{path}/par/*.par'))
    timfiles = sorted(glob(f'{path}/tim/*.tim'))
    assert len(parfiles) == len(timfiles)
    for p,t in zip(parfiles, timfiles):
        assert get_name(p) == get_name(t), f'{p, t}'
    return parfiles, timfiles

def make_dirs(path):
    if not os.path.exists(path):
        os.makedirs(path)
        os.makedirs(f'{path}/par')
        os.makedirs(f'{path}/tim')
    else:
        print(f'{path} already exists')
        import shutil
        shutil.rmtree(path)
        os.makedirs(path)
        os.makedirs(f'{path}/par')
        os.makedirs(f'{path}/tim')

def copy_partim(old_path, new_path, append_name=None):
    make_dirs(new_path)
    parfiles, timfiles = get_partim(old_path)
    for par, tim in zip(parfiles, timfiles):
        name = get_name(par)
        if append_name is not None:
            name += f'_{append_name}'
            
        os.system(f'cp {par} {new_path}/par/{name}.par')
        os.system(f'cp {tim} {new_path}/tim/{name}.tim')

def clean_par(path):
    parfiles = sorted(glob(f'{path}/par/*.par'))
    for par in tqdm(parfiles, desc='Cleaning par files'):
        with open(par) as f:
            lines = f.readlines()

            # To-remove lines:
            to_remove = ['EFAC','EQUAD','ECORR','RNAMP','RNIDX']
            clean = []
            for l in lines:
                if not any(r in l for r in to_remove):
                    clean.append(l)
                    
        with open(par, 'w') as f:
            f.writelines(clean)

def plot_rep_psr(psr):
    t = psr.toas.get_mjds()
    r = psr.residuals.time_resids.to_value('s')
    e = psr.residuals.get_data_error().to_value('s')

    plt.errorbar(t, r, e, fmt='.', capsize=3, label=f'{psr.name}')
    plt.xlabel('MJD')
    plt.ylabel('Residuals (s)')
    plt.legend()

def save_partim(psrs, path, name_append=None):
    for psr in tqdm(psrs, desc='Saving pulsars'):
        fname = f'{psr.name}_{name_append}' if name_append else f'{psr.name}'
        psr.write_partim(f'{path}/par/{fname}.par', f'{path}/tim/{fname}.tim', tempo2=False)

def get_backends(psr):
    return np.unique(psr.toas['f'])

# %% [markdown]
# ## Idealize the NG15 dataset
#
# I doubt you need to run this again

# %%
# Copy the par and tim files
copy_partim(NG15_path, ideal_path, append_name='ideal')

# Clean the par files
clean_par(ideal_path)

parfiles, timfiles = get_partim(ideal_path)
npsrs = len(parfiles)

def foo(i):
    psr = load_pulsar(parfiles[i], timfiles[i])
    make_ideal(psr)
    return psr

rep_psrs = [foo(i) for i in tqdm(range(npsrs), desc='Loading pulsars')]

with open(f'{ideal_path}/rep_psrs.pkl', 'wb') as f:
    pickle.dump(rep_psrs, f)

ent_psrs = [p.to_enterprise() for p in tqdm(rep_psrs, desc='Converting to enterprise')]

with open(f'{ideal_path}/enterprise_psrs.pkl', 'wb') as f:
    pickle.dump(ent_psrs, f)

save_partim(rep_psrs, ideal_path, name_append='ideal')
# Out:
# ../../datasets/ideal_NG15 already exists
# Cleaning par files: 100%|██████████| 67/67 [00:00<00:00, 5154.22it/s]
# Loading pulsars:  48%|████▊     | 32/67 [04:53<06:41, 11.46s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/models/stand_alone_psr_binaries/DDK_model.py:146 UserWarning: DDK model uses KIN as inclination angle. SINI will not be used. This happens every time a DDK model is constructed.
# Loading pulsars: 100%|██████████| 67/67 [09:50<00:00,  8.81s/it]
# Converting to enterprise:   4%|▍         | 3/67 [00:21<07:15,  6.80s/it]WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:   7%|▋         | 5/67 [00:46<10:14,  9.91s/it]WARNING: Could not find pulsar distance for PSR J0340+4130. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:   9%|▉         | 6/67 [00:50<08:07,  7.99s/it]WARNING: Could not find pulsar distance for PSR J0406+3039. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  12%|█▏        | 8/67 [00:57<05:25,  5.51s/it]WARNING: Could not find pulsar distance for PSR J0509+0856. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  13%|█▎        | 9/67 [00:59<04:15,  4.40s/it]WARNING: Could not find pulsar distance for PSR J0557+1551. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  15%|█▍        | 10/67 [01:00<03:11,  3.36s/it]WARNING: Could not find pulsar distance for PSR J0605+3757. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  16%|█▋        | 11/67 [01:01<02:28,  2.65s/it]WARNING: Could not find pulsar distance for PSR J0610-2100. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  19%|█▉        | 13/67 [01:20<06:05,  6.76s/it]WARNING: Could not find pulsar distance for PSR J0636+5128. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  21%|██        | 14/67 [01:48<11:43, 13.28s/it]WARNING: Could not find pulsar distance for PSR J0645+5158. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  22%|██▏       | 15/67 [01:52<09:06, 10.51s/it]WARNING: Could not find pulsar distance for PSR J0709+0458. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  24%|██▍       | 16/67 [01:55<06:52,  8.08s/it]WARNING: Could not find pulsar distance for PSR J0740+6620. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  25%|██▌       | 17/67 [02:07<07:44,  9.29s/it]WARNING: Could not find pulsar distance for PSR J0931-1902. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  28%|██▊       | 19/67 [02:31<09:11, 11.48s/it]WARNING: Could not find pulsar distance for PSR J1012-4235. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  33%|███▎      | 22/67 [02:40<04:43,  6.31s/it]WARNING: Could not find pulsar distance for PSR J1125+7819. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  34%|███▍      | 23/67 [02:47<04:44,  6.47s/it]WARNING: Could not find pulsar distance for PSR J1312+0051. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  36%|███▌      | 24/67 [02:49<03:33,  4.96s/it]WARNING: Could not find pulsar distance for PSR J1453+1902. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  40%|████      | 27/67 [03:20<06:50, 10.27s/it]WARNING: Could not find pulsar distance for PSR J1614-2230. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  42%|████▏     | 28/67 [03:37<07:55, 12.19s/it]WARNING: Could not find pulsar distance for PSR J1630+3734. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  46%|████▋     | 31/67 [04:10<07:36, 12.67s/it]WARNING: Could not find pulsar distance for PSR J1705-1903. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  49%|████▉     | 33/67 [05:34<17:15, 30.46s/it]WARNING: Could not find pulsar distance for PSR J1719-1438. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  52%|█████▏    | 35/67 [05:41<08:47, 16.48s/it]WARNING: Could not find pulsar distance for PSR J1738+0333. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  54%|█████▎    | 36/67 [05:47<06:58, 13.48s/it]WARNING: Could not find pulsar distance for PSR J1741+1351. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  57%|█████▋    | 38/67 [06:01<04:51, 10.05s/it]WARNING: Could not find pulsar distance for PSR J1745+1017. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  58%|█████▊    | 39/67 [06:03<03:38,  7.81s/it]WARNING: Could not find pulsar distance for PSR J1747-4036. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  60%|█████▉    | 40/67 [06:08<03:03,  6.79s/it]WARNING: Could not find pulsar distance for PSR J1751-2857. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  61%|██████    | 41/67 [06:09<02:17,  5.30s/it]WARNING: Could not find pulsar distance for PSR J1802-2124. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  63%|██████▎   | 42/67 [06:14<02:09,  5.16s/it]WARNING: Could not find pulsar distance for PSR J1811-2405. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  64%|██████▍   | 43/67 [06:19<01:59,  4.99s/it]WARNING: Could not find pulsar distance for PSR J1832-0836. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  66%|██████▌   | 44/67 [06:22<01:41,  4.42s/it]WARNING: Could not find pulsar distance for PSR J1843-1113. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  67%|██████▋   | 45/67 [06:24<01:20,  3.64s/it]WARNING: Could not find pulsar distance for PSR J1853+1303. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  69%|██████▊   | 46/67 [06:28<01:20,  3.84s/it]WARNING: Could not find pulsar distance for PSR J1903+0327. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  73%|███████▎  | 49/67 [07:18<03:34, 11.91s/it]WARNING: Could not find pulsar distance for PSR J1911+1347. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  76%|███████▌  | 51/67 [07:35<02:52, 10.78s/it]WARNING: Could not find pulsar distance for PSR J1923+2515. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  78%|███████▊  | 52/67 [07:37<02:01,  8.10s/it]WARNING: Could not find pulsar distance for PSR J1944+0907. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  79%|███████▉  | 53/67 [07:39<01:29,  6.38s/it]WARNING: Could not find pulsar distance for PSR J1946+3417. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  81%|████████  | 54/67 [07:44<01:14,  5.76s/it]WARNING: Could not find pulsar distance for PSR J2010-1323. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  82%|████████▏ | 55/67 [07:50<01:12,  6.04s/it]WARNING: Could not find pulsar distance for PSR J2017+0603. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  84%|████████▎ | 56/67 [07:54<00:58,  5.28s/it]WARNING: Could not find pulsar distance for PSR J2033+1734. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  85%|████████▌ | 57/67 [07:57<00:45,  4.59s/it]WARNING: Could not find pulsar distance for PSR J2043+1711. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  90%|████████▉ | 60/67 [08:25<00:59,  8.56s/it]WARNING: Could not find pulsar distance for PSR J2214+3000. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  91%|█████████ | 61/67 [08:31<00:46,  7.70s/it]WARNING: Could not find pulsar distance for PSR J2229+2643. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  93%|█████████▎| 62/67 [08:34<00:31,  6.31s/it]WARNING: Could not find pulsar distance for PSR J2234+0611. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  94%|█████████▍| 63/67 [08:37<00:21,  5.45s/it]WARNING: Could not find pulsar distance for PSR J2234+0944. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  96%|█████████▌| 64/67 [08:43<00:16,  5.47s/it]WARNING: Could not find pulsar distance for PSR J2302+4442. Setting value to 1 with 20% uncertainty.
# Converting to enterprise:  99%|█████████▊| 66/67 [09:03<00:08,  8.21s/it]WARNING: Could not find pulsar distance for PSR J2322+2057. Setting value to 1 with 20% uncertainty.
# Converting to enterprise: 100%|██████████| 67/67 [09:05<00:00,  8.14s/it]
# Saving pulsars: 100%|██████████| 67/67 [02:13<00:00,  1.99s/it]

# %% [markdown]
# ## Making a simulated dataset

# %%
make_dirs(sim_path)

# Start from ideal path
with open(f'{ideal_path}/rep_psrs.pkl', 'rb') as f:
    rep_psrs = pickle.load(f)

injected_params = {}
rng = np.random.default_rng(seed=420)
rseed = lambda : rng.integers(0, 2**32-1)

plot_rep_psr(rep_psrs[0])
plt.title(f'{rep_psrs[0].name} ideal');
# Out:
# ../../datasets/sim_NG15_01 already exists

# %% [markdown]
# ### White Noise

# %%
for psr in tqdm(rep_psrs, desc='Adding white noise'):
    backends = get_backends(psr)
    nbackends = len(backends)

    ef = rng.normal(loc=1.0, scale=0.2, size=nbackends)
    eq = rng.uniform(low=-8, high=-6, size=nbackends)
    ec = rng.uniform(low=-8, high=-6, size=nbackends)

    add_measurement_noise(psr, efac=ef, log10_equad=eq, flags=backends, seed=rseed())
    add_jitter(psr, log10_ecorr=ec, flags=backends, seed=rseed())
    
    injected_params.update({f'{psr.name}_{backends[i]}_efac': ef[i] for i in range(nbackends)})
    injected_params.update({f'{psr.name}_{backends[i]}_log10_t2equad': eq[i] for i in range(nbackends)})
    injected_params.update({f'{psr.name}_{backends[i]}_log10_ecorr': ec[i] for i in range(nbackends)})

    psr.fit()

plot_rep_psr(rep_psrs[0])
plt.title(f'{rep_psrs[0].name} WN');
# Out:
# Adding white noise:   1%|▏         | 1/67 [00:31<34:42, 31.55s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding white noise:  18%|█▊        | 12/67 [05:55<11:01, 12.03s/it] WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1035 MaxiterReached: Convergence not detected after 10 steps.
# Adding white noise:  48%|████▊     | 32/67 [21:03<25:01, 42.90s/it]  WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding white noise:  70%|███████   | 47/67 [33:59<06:25, 19.29s/it]   WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1035 MaxiterReached: Convergence not detected after 10 steps.
# Adding white noise:  82%|████████▏ | 55/67 [43:27<05:43, 28.67s/it] WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding white noise: 100%|██████████| 67/67 [47:55<00:00, 42.91s/it]

# %% [markdown]
# ### Intrinsic Red Noise

# %%
max_lkl_red ={
 'B1855+09': (3.3, -13.9), 'B1937+21': (3.7, -13.5), 'B1953+29': (2.9, -13.0),
 'J0023+0923': (1.2, -13.4), 'J0030+0451': (4.7, -14.4), 'J0340+4130': (2.6, -16.1),
 'J0406+3039': (1.5, -18.4), 'J0437-4715': (4.8, -17.1), 'J0509+0856': (0.51, -12.5),
 'J0557+1551': (5.6, -14.5), 'J0605+3757': (5.0, -14.2), 'J0610-2100': (1.6, -12.4),
 'J0613-0200': (2.6, -13.9), 'J0636+5128': (4.7, -19.8), 'J0645+5158': (0.25, -13.3),
 'J0709+0458': (2.3, -12.3), 'J0740+6620': (0.81, -14.3), 'J0931-1902': (2.6, -17.5),
 'J1012+5307': (0.046, -12.6), 'J1012-4235': (2.6, -17.4), 'J1022+1001': (3.5, -14.0),
 'J1024-0719': (2.2, -13.9), 'J1125+7819': (6.2, -15.1), 'J1312+0051': (1.4, -12.7),
 'J1453+1902': (2.9, -17.0), 'J1455-3330': (1.7, -15.3), 'J1600-3053': (3.1, -19.5),
 'J1614-2230': (0.9, -13.9), 'J1630+3734': (3.0, -16.7), 'J1640+2224': (6.8, -18.1),
 'J1643-1224': (1.5, -12.3), 'J1705-1903': (0.1, -12.2), 'J1713+0747': (0.8, -14.4),
 'J1719-1438': (4.1, -14.2), 'J1730-2304': (2.9, -13.1), 'J1738+0333': (5.7, -14.9),
 'J1741+1351': (2.0, -14.3), 'J1744-1134': (4.9, -17.3), 'J1745+1017': (2.0, -11.8),
 'J1747-4036': (3.0, -12.6), 'J1751-2857': (2.2, -19.3), 'J1802-2124': (0.2, -12.2),
 'J1811-2405': (4.0, -16.8), 'J1832-0836': (0.7, -19.7), 'J1843-1113': (1.7, -14.2),
 'J1853+1303': (1.1, -13.2), 'J1903+0327': (1.3, -12.1), 'J1909-3744': (5.4, -18.7),
 'J1910+1256': (0.87, -18.4), 'J1911+1347': (1.8, -14.2), 'J1918-0642': (6.1, -18.6),
 'J1923+2515': (2.8, -15.3), 'J1944+0907': (3.2, -13.7), 'J1946+3417': (1.0, -12.5),
 'J2010-1323': (0.03, -18.0), 'J2017+0603': (1.9, -17.0), 'J2033+1734': (5.1, -17.3),
 'J2043+1711': (2.5, -14.5), 'J2124-3358': (1.8, -16.7), 'J2145-0750': (0.5, -12.9),
 'J2214+3000': (3.6, -19.7), 'J2229+2643': (3.3, -17.9), 'J2234+0611': (4.5, -14.3),
 'J2234+0944': (4.8, -17.0), 'J2302+4442': (0.1, -18.1), 'J2317+1439': (3.7, -16.5),
 'J2322+2057': (3.5, -14.9),
}

# %%
for psr in tqdm(rep_psrs, desc='Adding intrinsic red noise'):
    gamma, log10_A = max_lkl_red[psr.name]
    add_red_noise(psr, log10_A, gamma, seed=rseed(), components=100)
    injected_params.update({f'{psr.name}_irn_log10_A': log10_A, f'{psr.name}_irn_gamma': gamma})

    psr.fit()

plot_rep_psr(rep_psrs[0])
plt.title(f'{rep_psrs[0].name} WN+IRN');
# Out:
# Adding intrinsic red noise:   1%|▏         | 1/67 [00:23<25:22, 23.07s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding intrinsic red noise:  18%|█▊        | 12/67 [03:50<08:07,  8.86s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1035 MaxiterReached: Convergence not detected after 10 steps.
# Adding intrinsic red noise:  48%|████▊     | 32/67 [16:09<23:24, 40.12s/it]  WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding intrinsic red noise:  82%|████████▏ | 55/67 [30:26<04:12, 21.00s/it]   WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# Adding intrinsic red noise: 100%|██████████| 67/67 [34:03<00:00, 30.49s/it]

# %% [markdown]
# ### Gravitational wave background

# %%
gwb_log10_A = np.log10(2.4e-15)
gwb_gamma = 13/3

add_gwb(rep_psrs, gwb_log10_A, gwb_gamma, seed=rseed())

injected_params.update({'gwb_log10_A': gwb_log10_A, 'gwb_gamma': gwb_gamma})

# %%
[p.fit() for p in tqdm(rep_psrs)]

plot_rep_psr(rep_psrs[0])
plt.title(f'{rep_psrs[0].name} WN+IRN+GWB');
# Out:
#   1%|▏         | 1/67 [00:32<35:17, 32.08s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
#  48%|████▊     | 32/67 [14:30<23:44, 40.71s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
#  70%|███████   | 47/67 [23:23<04:52, 14.64s/it]   WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
#  82%|████████▏ | 55/67 [29:29<04:11, 20.93s/it]WARNING  (pint.logging                  ): /home/kyleg/miniforge3/envs/atlas/lib/python3.12/site-packages/pint/fitter.py:1031 StepProblem: Unable to improve chi2 even with very small steps
# 100%|██████████| 67/67 [33:32<00:00, 30.04s/it]

# %% [markdown]
# ### Continuous waves
#
# If needed, this is where CW injections go

# %%
pass

# %% [markdown]
# ### Outputing to the par and tim files

# %%
with open(f'{sim_path}/rep_psrs.pkl', 'wb') as f:
    pickle.dump(rep_psrs, f)

save_partim(rep_psrs, sim_path, 'sim')

with open(f'{sim_path}/injected_params.json', 'w') as f:
    json.dump(injected_params, f)

e_psrs = [e.to_enterprise() for e in rep_psrs]

with open(f'{sim_path}/enterprise_psrs.pkl', 'wb') as f:
    pickle.dump(e_psrs, f)
# Out:
# Saving pulsars: 100%|██████████| 67/67 [02:25<00:00,  2.18s/it]
# WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0340+4130. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0406+3039. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0509+0856. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0557+1551. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0605+3757. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0610-2100. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0636+5128. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0645+5158. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0709+0458. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0740+6620. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0931-1902. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1012-4235. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1125+7819. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1312+0051. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1453+1902. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1614-2230. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1630+3734. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1705-1903. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1719-1438. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1738+0333. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1741+1351. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1745+1017. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1747-4036. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1751-2857. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1802-2124. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1811-2405. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1832-0836. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1843-1113. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1853+1303. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1903+0327. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1911+1347. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1923+2515. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1944+0907. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1946+3417. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2010-1323. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2017+0603. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2033+1734. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2043+1711. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2214+3000. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2229+2643. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2234+0611. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2234+0944. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2302+4442. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2322+2057. Setting value to 1 with 20% uncertainty.

# %%
# Start from ideal path
with open(f'{ideal_path}/rep_psrs.pkl', 'rb') as f:
    rep_psrs = pickle.load(f)

with open(f'{sim_path}/enterprise_psrs.pkl', 'rb') as f:
    ent_psrs = pickle.load(f)

tm_params = {}
for i in range(len(ent_psrs)):
    params = ent_psrs[i].fitpars[1:] # Ignore offset
    # True values from noise-less fit
    values = [rep_psrs[i].model[p].value for p in params]

    # Add back offset
    params = ent_psrs[i].fitpars
    values.insert(0, np.nan)

    # Add these to the tm_params dictionary
    tm_params[ent_psrs[i].name] = {p: v for p, v in zip(params, values)}

with open(f'{sim_path}/tm_params.pkl', 'wb') as f:
    pickle.dump(tm_params, f)

# %% [markdown]
# ## Plotting residuals for all pulsars

# %%
for p in rep_psrs:
    plot_rep_psr(p)
    plt.title(f'{p.name} WN+IRN+GWB')
    plt.show()
