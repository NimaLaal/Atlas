# %%
import sys
sys.path.append('/data/taylor_group/Nima/ATLAS')

import json
import pickle
import copy 
import random 
import glob

from tqdm.auto import trange
import tqdm_joblib
from joblib import Parallel, delayed

import numpy as np
import jax.numpy as jnp
import jax.random as jrandom
import jax
jax.config.update("jax_enable_x64", True)

import numpyro
import numpyro.distributions as dist
from numpyro.infer import MCMC, NUTS
from numpyro.distributions import constraints

from jug.engine.session import TimingSession

from ATLAS.data import PTA_Data
from ATLAS.signals.factorized.base import Red, SuperSignal
from ATLAS.signals.correlated.base import Correlated
from ATLAS import parameterized
from ATLAS.signals.timing.base import build_multi_psr_timing_model, MultiPsrTimingModel
from ATLAS.signals.timing.base import setup_timing_model
from ATLAS.nMatrix.base import WhiteCov
from ATLAS.signals import signals_utils as sutils
import ATLAS.utils as atlas_utils
import ATLAS.signals.factorized.utils as unc_utils
import ATLAS.signals.correlated.utils as cor_utils
from ATLAS import pulsar

# import MultiHMCGibbs

from ATLAS.samplers.canetoadracing import MultiHMCGibbs, MultiHMCGibbsWithAnalytic, AnalyticRhoTransition

# %load_ext autoreload
# %autoreload 2
# Out:
# libstempo not installed. PINT or libstempo are required to use par and tim files.

# %%
import matplotlib.pyplot as plt
hist_settings = dict(
    bins = 'auto',
    histtype = 'step', 
    lw = 3,
    density = True
)

plt.style.use('default')
def figsize(scale, wc = 1, hc = 1):
    fig_width_pt = 513.17 #469.755                  # Get this from LaTeX using \the\textwidth
    inches_per_pt = 1.0/72.27                       # Convert pt to inch
    golden_mean = (np.sqrt(5.0)-1.0)/2.0            # Aesthetic ratio (you could change this)
    fig_width = fig_width_pt*inches_per_pt*scale    # width in inches
    fig_height = fig_width*golden_mean              # height in inches
    fig_size = [wc * fig_width,hc * fig_height]
    return fig_size
plt.rcParams.update(plt.rcParamsDefault)

params = {#'backend': 'pdf',
        'axes.labelsize': 12,
        'lines.markersize': 4,
        'font.size': 10,
        'xtick.major.size':6,
        "xtick.top": True,
        "ytick.right": True,
        "xtick.minor.visible": True,
        "xtick.major.top": True, 
        "xtick.minor.top": True,
        "ytick.minor.visible": True, 
        "ytick.major.right": True, 
        "ytick.minor.right": True,
        "ytick.direction": "in",
        "xtick.direction": "in",
        'xtick.minor.size':3,  
        'ytick.major.size':6,
        'ytick.minor.size':3, 
        'xtick.major.width':0.5,
        'ytick.major.width':0.5,
        'xtick.minor.width':0.5,
        'ytick.minor.width':0.5,
        'lines.markeredgewidth':1,
        'axes.linewidth':1.2,
        'legend.fontsize': 7,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'savefig.dpi':200,
        'path.simplify':True,
        'font.family': 'serif',
        'font.serif':'Times',
        # "text.usetex": True,
        #'text.latex.preamble': [r'\usepackage{amsmath}'],
        'text.usetex':False,
        'figure.figsize': figsize(0.5, 1, 1)}
plt.rcParams.update(params)
plt.rcParams['font.family'] = 'STIXGeneral'  # Closely matches Computer Modern
plt.rcParams['mathtext.fontset'] = 'stix'    # Use STIX for math

# %% [markdown]
# # Loading data

# %% [markdown]
# ## Option 1: To test the full capability of `ATLAS`, we only need par and tim files.

# %% [markdown]
# ### We are using the `enterprise` pulsar object. This will be replaced by an in-house object very soon.

# %%
from enterprise.pulsar import Pulsar

# %%
pnames = ['B1855+09', 'B1937+21', 'B1953+29', 'J0023+0923', 'J0030+0451', 'J0340+4130', 'J0406+3039', 
'J0437-4715', 'J0509+0856', 'J0557+1551', 'J0605+3757', 'J0610-2100', 'J0613-0200', 'J0636+5128', 
'J0645+5158', 'J0709+0458', 'J0740+6620', 'J0931-1902', 'J1012+5307', 'J1012-4235', 'J1022+1001', 
'J1024-0719', 'J1125+7819', 'J1312+0051', 'J1453+1902', 'J1455-3330', 'J1600-3053', 'J1614-2230', 
'J1630+3734', 'J1640+2224', 'J1643-1224', 'J1705-1903', 'J1713+0747', 
'J1719-1438', 'J1730-2304', 
'J1738+0333', 'J1741+1351', 'J1744-1134', 'J1745+1017', 'J1747-4036', 'J1751-2857', 'J1802-2124', 
'J1811-2405', 'J1832-0836', 'J1843-1113', 'J1853+1303', 'J1903+0327', 'J1909-3744', 'J1910+1256', 
'J1911+1347', 'J1918-0642', 'J1923+2515', 'J1944+0907', 'J1946+3417', 'J2010-1323', 'J2017+0603', 
'J2033+1734', 'J2043+1711', 'J2124-3358', 'J2145-0750', 'J2214+3000', 'J2229+2643', 'J2234+0611', 
'J2234+0944', 'J2302+4442', 'J2317+1439', 'J2322+2057']
len(pnames)
# Out:
# 67

# %%
parfiles_ref = sorted(glob.glob('../data/NG15/partim/par/*.par'))
timfiles_ref = sorted(glob.glob('../data/NG15/partim/tim/*.tim'))

# %% [markdown]
# ### Filter the par and tim files to remove "ao-only" files

# %%
parfiles = []
for pname in pnames:
    for p in parfiles_ref:
        if pname in p and not 'ao' in p and not 'gbt' in p:
            parfiles.append(p)

timfiles = []
for pname in pnames:
    for p in timfiles_ref:
        if pname in p and not 'ao' in p and not 'gbt' in p:
            timfiles.append(p)

# %%
assert len(parfiles) == len(pnames)

# %%
Npulsars = len(pnames) # how many pulsars do you want?
Npulsars
# Out:
# 67

# %%
# def doit(pidx):
#     return Pulsar(parfiles[pidx], timfiles[pidx], sort=True, ephem='DE440', timing_package='PINT')
# with tqdm_joblib.tqdm_joblib(desc="PINT Loading...", total=len(parfiles)) as progress_bar:
#     psrs = Parallel(n_jobs=24)(delayed(doit)(i) for i in range(len(parfiles)))
#     # psrs = Parallel(n_jobs=24)(delayed(doit)(i) for i in range(1))

# with open('../data/NG15/NG15_v1p1_final_pint_psrs_sorted.pkl', 'wb') as fout:
#     pickle.dump(psrs, fout)

# %%
with open('../data/NG15/NG15_v1p1_final_pint_psrs_sorted.pkl', 'rb') as fin:
    psrs = pickle.load(fin)
psrs = [psr for psr in psrs if psr.name != 'J1713+0747']

# %%
with open('../data/NG15/15yr_wn_dict.json', 'r') as fin:
    noise_dict = json.load(fin)

# %%
chosen_pidx = 0 #np.argmin([len(psr.toas) for psr in psrs])
chosen_pidx
# Out:
# 0

# %%
psrs = psrs[chosen_pidx :chosen_pidx +1]

# %%
len(psrs)
# Out:
# 1

# %%
psrs[0].name
# Out:
# 'B1855+09'

# %%
timfiles[chosen_pidx :chosen_pidx +1]
# Out:
# ['../data/NG15/partim/tim/B1855+09_PINT_20220301.nb.tim']

# %% [markdown]
# ## Option 2: If you do not want to vary the timing model params, use the pre-made 15 year pulsar objects.

# %%
from enterprise.pulsar import FeatherPulsar
import glob

feather_files = glob.glob('/data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/*.feather')
psrs = []
for feather_file in feather_files:
    psr = FeatherPulsar.read_feather(feather_file)
    psrs.append(psr)

with open('/data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/15yr_wn_dict.json', 'r') as fin:
    noise_dict = json.load(fin)
# Out:
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1855+09.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1855+09.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1855+09.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1937+21.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1937+21.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1937+21.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1953+29.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1953+29.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-B1953+29.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0023+0923.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0023+0923.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0023+0923.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0030+0451.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0030+0451.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0030+0451.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0340+4130.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0340+4130.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0340+4130.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0406+3039.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0406+3039.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0406+3039.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0437-4715.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0437-4715.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0437-4715.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0509+0856.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0509+0856.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0509+0856.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0557+1551.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0557+1551.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0557+1551.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0605+3757.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0605+3757.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0605+3757.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0610-2100.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0610-2100.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0610-2100.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0613-0200.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0613-0200.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0613-0200.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0636+5128.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0636+5128.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0636+5128.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0645+5158.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0645+5158.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0645+5158.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0709+0458.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0709+0458.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0709+0458.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0740+6620.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0740+6620.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0740+6620.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0931-1902.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0931-1902.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J0931-1902.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012+5307.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012+5307.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012+5307.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012-4235.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012-4235.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1012-4235.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1022+1001.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1022+1001.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1022+1001.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1024-0719.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1024-0719.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1024-0719.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1125+7819.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1125+7819.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1125+7819.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1312+0051.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1312+0051.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1312+0051.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1453+1902.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1453+1902.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1453+1902.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1455-3330.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1455-3330.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1455-3330.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1600-3053.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1600-3053.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1600-3053.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1614-2230.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1614-2230.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1614-2230.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1630+3734.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1630+3734.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1630+3734.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1640+2224.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1640+2224.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1640+2224.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1643-1224.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1643-1224.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1643-1224.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1705-1903.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1705-1903.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1705-1903.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1713+0747.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1713+0747.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1713+0747.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1719-1438.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1719-1438.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1719-1438.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1730-2304.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1730-2304.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1730-2304.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1738+0333.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1738+0333.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1738+0333.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1741+1351.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1741+1351.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1741+1351.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1744-1134.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1744-1134.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1744-1134.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1745+1017.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1745+1017.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1745+1017.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1747-4036.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1747-4036.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1747-4036.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1751-2857.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1751-2857.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1751-2857.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1802-2124.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1802-2124.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1802-2124.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1811-2405.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1811-2405.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1811-2405.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1832-0836.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1832-0836.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1832-0836.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1843-1113.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1843-1113.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1843-1113.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1853+1303.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1853+1303.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1853+1303.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1903+0327.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1903+0327.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1903+0327.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1909-3744.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1909-3744.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1909-3744.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1910+1256.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1910+1256.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1910+1256.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1911+1347.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1911+1347.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1911+1347.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1918-0642.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1918-0642.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1918-0642.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1923+2515.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1923+2515.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1923+2515.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1944+0907.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1944+0907.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1944+0907.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1946+3417.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1946+3417.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J1946+3417.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2010-1323.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2010-1323.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2010-1323.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2017+0603.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2017+0603.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2017+0603.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2033+1734.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2033+1734.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2033+1734.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2043+1711.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2043+1711.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2043+1711.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2124-3358.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2124-3358.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2124-3358.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2145-0750.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2145-0750.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2145-0750.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2214+3000.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2214+3000.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2214+3000.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2229+2643.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2229+2643.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2229+2643.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0611.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0611.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0611.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0944.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0944.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2234+0944.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2302+4442.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2302+4442.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2302+4442.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2317+1439.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2317+1439.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2317+1439.feather.
# FeatherPulsar.read_feather: cannot find fitpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2322+2057.feather.
# FeatherPulsar.read_feather: cannot find setpars in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2322+2057.feather.
# FeatherPulsar.read_feather: cannot find _pdist in feather file /data/taylor_group/Nima/15yr_stochastic_analysis/tutorials/data/feathers/v1p1_de440_pint_bipm2019-J2322+2057.feather.

# %%
psrs = psrs[0:1]

# %%
data = PTA_Data(psrs, 
                fixed_res = False,
                marg_timing=True, 
                diag_white_cov=False,
                linear_timing = True)

# %% [markdown]
# # Model Construction

# %% [markdown]
# ## White Noise Model

# %%
wn_model = WhiteCov(data = data)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Timing Model

# %%
# SAMPLE = ['F0', 'F1'] #psrs[0].fitpars[1:] #['F0', 'F1']
# tm_model = build_multi_psr_timing_model(parfiles[chosen_pidx :chosen_pidx + 1], 
#                                         timfiles[chosen_pidx :chosen_pidx + 1], 
#                                         SAMPLE, 
#                                         load_how_many_in_parallel = 24,
#                                         data = data)
# # data.add_timing_design_matrix(tm_model.Mmats)
# svd_norm_mmat = _timing_model_svd(psrs[0].Mmat)
# data.add_timing_design_matrix([svd_norm_mmat])

# %%
raw_res = jnp.concat(data.raw_residuals)

# %% [markdown]
# ### Initial white noise guess

# %%
theta0_wn = wn_model.prior_draw()
theta0_wn = wn_model.params_dict_to_vector(noise_dict)
theta0_wn[:5]
# Out:
# Array([ 1.11593531,  1.00004904,  1.04311402,  1.11184323, -7.56416433],      dtype=float64)

# %% [markdown]
# ## Red Noise Model

# %%
non_gwb_nfreqs = 30

# %% [markdown]
# ### Non-GWB Model

# %% [markdown]
# #### Choose your PSD model

# %%
# Example:
# chosen_psd_model_nongwb, helper_dictionary_nongwb = unc_utils.varied_gamma_pl(renorm_const = 1)
chosen_psd_model_nongwb, helper_dictionary_nongwb = unc_utils.spectrum(renorm_const = 1, crn_bins = non_gwb_nfreqs)

# %%
sig_unc = Red(name='cor', 
                nfreqs=non_gwb_nfreqs, 
                halflog10_rho_range=(-9,-2),
                data = data,
                use_pulsar_tspan = False)

# %% [markdown]
# ### The user should not see this in the final version, but for now you need to see this!

# %%
signal_helper = {
    'shared_basis': { #shared basis does not mean the nfreqs are the same between signals.
                    #It means that one basis includes the other one.
    'signal_list': [sig_unc], 
    'index_of_signal_used_for_basis': 0,
    },

    'separate': {
        'signal_list': []
        },
    'order': 'cor',
    }

# %%
sig = SuperSignal(signal_helper = signal_helper, 
                data=data,
)

# %% [markdown]
# ### `sig.get_helpers` updates the white noise covaraince matrix

# %%
TNT, TNr, rNr, logdetN = sig.get_helpers(reff = raw_res, white_noise_params=theta0_wn)
helpers = (TNT, TNr, rNr, logdetN)
TNT.shape, TNr.shape, rNr.shape, logdetN.shape
# Out:
# ((1, 60, 60), (1, 60), (), ())

# %%
ll, ul = wn_model.get_prior_bounds() #white noise prior bounds
ll[:5], ul[:5]
# Out:
# (Array([ 0.01,  0.01,  0.01,  0.01, -9.  ], dtype=float64),
#  Array([10., 10., 10., 10., -5.], dtype=float64))

# %%
sig_unc.tspans/(86400 * 365.25)
# Out:
# 15.585070202331154

# %%
Tspan = sig_unc.tspans
o = parameterized.SinglePulsarRedNoise(
            int_bins = non_gwb_nfreqs,
            f_intrin = sig_unc.freqs,
            df = 1/Tspan,
            Tspan = Tspan, 
            renorm_const = 1,
            # ---- non-GWB intrinsic red noise (optional) ----
            irn_psd_func=chosen_psd_model_nongwb,
            irn_helper_dictionary=helper_dictionary_nongwb,
            )
sig.add_parameterization(o)

# %%
x0 = o.make_initial_guess(jrandom.key(1273442)) #red noise model params
phi0 = o.get_phi_mat_full(x0) #red noise cov matrix
phi0.shape, x0.shape
# Out:
# ((30, 1), (30,))

# %% [markdown]
# # Likelihood

# %% [markdown]
# ### Reparameterized likelihood

# %%
z0 = jrandom.normal(jrandom.key(10098), shape = (sig.npsrs, sig.nmodes)) # re-parameterized coefficients

# %%
lnprob0, coeff0 = sig.lnposterior_reparam(helpers = helpers, 
                                            red_params = x0, 
                                            z = z0)
lnprob0
# Out:
# Array(91141.09991791, dtype=float64)

# %%
def model():

    z = numpyro.sample('z_red', dist.Normal().expand([sig.npsrs, sig.nmodes]))

    rn_params = numpyro.sample('rn_params', dist.Uniform(o.lower_prior_lim_all, o.upper_prior_lim_all))

    lnpost_val, a = sig.lnposterior_reparam(helpers=helpers, red_params=rn_params, z=z)

    # numpyro.deterministic('a', a)
    numpyro.factor('lnpost', lnpost_val + 0.5 * jnp.sum(z**2))

# %%
nuts_kernel = numpyro.infer.NUTS(model=model)
mcmc = numpyro.infer.MCMC(sampler=nuts_kernel,
                          num_warmup=1000,
                          num_samples=4000,
                          num_chains=1,
                          )
mcmc.run(jrandom.key(12887))
atlas_helpers_samples = mcmc.get_samples()
# Out:
# sample: 100%|██████████| 5000/5000 [01:02<00:00, 79.90it/s, 31 steps of size 1.55e-01. acc. prob=0.91]

# %%
plt.hist(atlas_helpers_samples['rn_params'][:, 0], **hist_settings)
plt.show()

# %%
# %timeit lnprob0, coeff0 = sig.lnposterior_reparam(helpers = (TNT, TNr), red_params = x0, z = z0)

# %%
from enterprise_extensions import blocks
from enterprise.signals import signal_base, gp_signals
from enterprise.pulsar import Pulsar
from astropy.time import TimeDelta
from pint.simulation import make_fake_toas_fromMJDs
import astropy.units as u
from pint.models import get_model

from enterprise_extensions import sampler
from enterprise.signals import parameter
from enterprise.signals import gp_priors
# Out:
# Optional mpi4py package is not installed.  MPI support is not available.

# %%
s = gp_signals.MarginalizingTimingModel(use_svd=True, normed = True)
# s = gp_signals.TimingModel(use_svd=True)
s += blocks.white_noise_block(
    vary=True,
    inc_ecorr=True,
    gp_ecorr=False,
    select='backend',
    tnequad=False,
)

# log10_A = parameter.Uniform(-18., -11.)('log10A')
# gamma = parameter.Uniform(0., 7.)('gamma')

# s+= gp_signals.FourierBasisGP(
#     spectrum=gp_priors.powerlaw(log10_A=log10_A, gamma = gamma),
#     modes = sig_unc.freqs,
#     # components = len(sig_unc.freqs),
#     Tspan=Tspan,
#     name="red_noise",
# )
log10_rho = parameter.Uniform(-9., -2., size=len(sig_unc.freqs))
s+= gp_signals.FourierBasisGP(
    spectrum=gp_priors.free_spectrum(log10_rho=log10_rho),
    components=len(sig_unc.freqs),
    modes = sig_unc.freqs,
    Tspan=Tspan,
    # name="red_noise",
)

pta = signal_base.PTA(
    [s(p) for p in psrs], signal_base.LogLikelihoodDenseCholesky
)

# %% [markdown]
# # Timing Model

# %% [markdown]
# ### `z_tm` is the value by which the deviations from the best fit are changed. This is an inferable parameter

# %%
z_tm = {}
for pidx in range(sig.npsrs):
    z_tm.update({f'z_{k};{pidx}': 100 * jrandom.normal(jrandom.key(random.randint(0, 16162))) for k in SAMPLE})
z_tm

# %%
z_tm_concat = jnp.array(list(z_tm.values()))
assert z_tm_concat.shape[0] == len(psrs) * len(SAMPLE)

# %%
tm_model.residuals(z_tm_concat),tm_model.residuals(z_tm_concat).shape

# %%
# %timeit tm_model.residuals(z_tm_concat)

# %%
# z_tm_concat = tm_model.get_epsilon(helpers = (MNM, MNr), key = jrandom.key(12))

# %%
# tm_model.linear_residuals(z_tm_concat)

# %%
tm_param_dim = len(z_tm_concat)
tm_param_dim

# %% [markdown]
# # Sampling

# %% [markdown]
# ### NOTE: Comment out the parts of the model you do not want to sample

# %% [markdown]
# ### NOTE: If you want to fix the white noise to the NG15 noise dictionary, make sure you use the white noise dictionary to make the TNT, TNr matricies instead of prior draws.

# %%
def model():

    ######################################## Timing Model ########################################
    # Declare the variables in the model
    z_tm_concat = numpyro.sample('z_tm_concat', dist.Normal(0, 100).expand([tm_param_dim]))
    stochastic_res = tm_model.residuals(z_tm_concat)
    ######################################## White Noise ########################################
    # Declare the variables in the model
    theta_wn = numpyro.sample('theta_wn', dist.Uniform(ll, ul))

    # Update the white noise covaraince matrix
    TNT, TNr, rNr, logdet_N = sig.get_helpers(reff = stochastic_res, 
                                              white_noise_params=theta_wn
                                             )

    # White noise direct contribution to the PTA likelihood
    numpyro.factor('lnpost_white', -0.5 * (rNr[0] + logdet_N))

    ######################################## Red Noise ########################################
    # Declare the variables in the model
    xs = numpyro.sample('xs', dist.Uniform(o.lower_prior_lim_all, o.upper_prior_lim_all)) #PSD params
    z_a = numpyro.sample('z_a', dist.Normal(0, 1).expand((sig.npsrs, sig.nmodes))) #the reparam coefficients

    # evaluate the posterior
    lprob, coeff = sig.lnposterior_reparam(helpers = (TNT, TNr), red_params = xs, z = z_a)
    numpyro.factor('lnpost', lprob)

    numpyro.deterministic('coeff', coeff)

# %% [markdown]
# ## Not Block Gibbs

# %%
mcmc_bad = MCMC(
    NUTS(model),
    num_warmup=1000,
    num_samples=4000,
    num_chains=1,
    # chain_method=chain_method,
    progress_bar=True
)
mcmc_bad.run(jrandom.key(100))

# %%
samples = mcmc_bad.get_samples()['xs']
samples.shape

# %%
for fidx in range(30):
    plt.hist(samples[:, fidx], **hist_settings)
    plt.show()

# %% [markdown]
# ## Block Gibbs

# %%
kernel = MultiHMCGibbsWithAnalytic(
        [
        NUTS(model), 
        AnalyticRhoTransition(model = model,
                            posterior_draw_func = tm_model.get_epsilon,
                            prior_draw_func = epsilon_prior_draw
                            rho_site  = "epsilons",
                            coeff_site = "coeff",
                            rho_low  = -9.0,
                            rho_high = -2.0)
        ],
        
        [
        ['z_tm_concat', 'z_a'],
        ['xs']
        ]
    )

kernel = NUTS(model, max_tree_depth=8, target_accept_prob=0.8, dense_mass=False)

# %%
mcmc_bad = MCMC(
    kernel,
    num_warmup=1000,
    num_samples=4000,
    num_chains=1,
    # chain_method=chain_method,
    progress_bar=True
)
mcmc_bad.run(jrandom.key(100))

# %%
samples = mcmc_bad.get_samples()['xs']
samples.shape

# %%
samples[:, -1]

# %%
plt.plot(samples[:, -1])
plt.show()

# %% [markdown]
# # ENTERPRISE

# %%
from enterprise_extensions.gibbs_sampling import gibbs

# %%
m = gibbs.BayesPowerSingle(psr=psrs[0],
        Tspan=None,
        select="backend",
        white_vary=True,
        inc_ecorr=True,
        ecorr_type="kernel",
        noise_dict=noise_dict,
        tm_marg=False,
        freq_bins=30,
        tnequad=False,
        log10rhomin=-9.0,
        log10rhomax=-4.0)

# %%
# good_idxs = [psrs[0].fitpars.index('F0'), psrs[0].fitpars.index('F1')] + m.gwid[0].tolist()
good_idxs = [psrs[0].fitpars.index(x) for x in SAMPLE] + m.gwid[0].tolist()
good_idxs = np.array(good_idxs)
# good_idxs = np.arange(m.Tmat.shape[-1])
good_idxs

# %%
keep_idxs = np.ix_(good_idxs, good_idxs)

# %%
# m = gibbs.BayesPowerSingle(psr=psrs[0],
#         Tspan=None,
#         select="backend",
#         white_vary=False,
#         inc_ecorr=True,
#         ecorr_type="kernel",
#         noise_dict=noise_dict,
#         tm_marg=False,
#         freq_bins=30,
#         tnequad=False,
#         log10rhomin=-9.0,
#         log10rhomax=-4.0,
#         keep_coeff_idxs = keep_idxs)

# %%
m.sample(
        niter=int(1e4),
        wniters=30,
        eciters=10,
        savepath='/data/taylor_group/Nima/PandorasBox/Trash/GibbsTrashCan',
        SCAMweight=30,
        AMweight=15,
        DEweight=50,
        covUpdate=1000,
        burn=10000,)

# %%
chain = np.load('/data/taylor_group/Nima/PandorasBox/Trash/GibbsTrashCan/chain_1.npy', mmap_mode = 'r')
chain.shape

# %%
chain = chain[int(0.25 * chain.shape[0]):, :]
chain.shape

# %%
for fidx in range(5):
    plt.plot(chain[:, fidx])
    plt.show()

# %%
chain.shape

# %%
60 + 30 +  tm_model.Mmats[0].shape[-1]

# %%
for fidx in range(30):
    plt.hist(chain[:, fidx], **hist_settings, label = 'ENTERPRISE')
    # plt.hist(samples[:, fidx], **hist_settings, label = 'ATLAS')
    # plt.title(m.pta.param_names[fidx])
    plt.legend()
    plt.show()

# %% [markdown]
# # Flows

# %%
from Atlas.flows import Flow

# %%
mm = Flow(data = jnp.array(chain),
        flow_num_layers=4,
        hidden_size=128,
        mlp_num_layers=2,
        num_bins=8,
        learning_rate=1e-4,
        B=6.0,
        p=0.3,
        seed=0
         )

# %%
mm.fit()

# %%
gen_samps = mm.sample((int(1e4)))

# %%
plt.hist(gen_samps[:, 23], **hist_settings)
plt.hist(chain[:, 23], **hist_settings)
plt.show()

# %%
z = mm.backward_pass(gen_samps)
z.shape

# %%
plt.hist(z[:, 23], **hist_settings)
plt.show()

# %%
chain.shape[-1]

# %%
from numpyro.distributions import constraints
from numpyro.distributions.constraints import Constraint
from numpyro.distributions.transforms import Transform
from jax.tree_util import register_pytree_node_class
from numpyro.infer.reparam import ExplicitReparam
from numpyro import handlers

# %%
# @register_pytree_node_class
class FlowReparam(Transform):
    r"""
    """

    domain = constraints.real
    
    def __init__(
        self, flow_object
    ):
        self.flow_object = flow_object
        
    def __call__(self, x):
        return self.flow_object.forward_pass(x)

    def _inverse(self, y):
        return self.flow_object.backward_pass(y)

    def log_abs_det_jacobian(self, x, y, intermediates):
        _, total_logdet = self.flow_object.forward_pass_with_logdet(x)
        return total_logdet

    def tree_flatten(self):
        # flow_object is the dynamic part
        return ((self.flow_object,), None)

    @classmethod
    def tree_unflatten(cls, aux_data, children):
        return cls(*children)

# %%
flow_prior = dist.TransformedDistribution(
    dist.Normal(0,1).expand([chain.shape[-1]]).to_event(1),
    FlowReparam(mm)
)

# %%
def model():
    z = numpyro.sample("z", dist.Normal(0,1).expand([chain.shape[-1]]).to_event(1))
    x, total_logdet = mm.forward_pass_with_logdet(z)
    numpyro.factor('lnprob', mm.log_prob(x) + 0.5 * jnp.sum(z**2) + total_logdet)
    numpyro.deterministic('x', x)
    
kernel = NUTS(model)
mcmc = MCMC(kernel, num_warmup=1000, num_samples=1000, num_chains=1)
mcmc.run(jrandom.key(2))

# %%
x = mcmc.get_samples()['x']
x.shape

# %%
plt.hist(gen_samps[:, 23], **hist_settings)
plt.hist(x[:, 0, 23],  **hist_settings)
plt.show()

# %%
from enterprise_extensions import blocks
from enterprise.signals import signal_base, gp_signals
from enterprise.pulsar import Pulsar
from astropy.time import TimeDelta
from pint.simulation import make_fake_toas_fromMJDs
import astropy.units as u
from pint.models import get_model

from enterprise_extensions import sampler
from enterprise.signals import parameter
from enterprise.signals import gp_priors

# %%
s = gp_signals.TimingModel(use_svd=True)
s += blocks.white_noise_block(
    vary=True,
    inc_ecorr=True,
    gp_ecorr=False,
    select='backend',
    tnequad=False,
)

# log10_A = parameter.Uniform(-18., -11.)('log10A')
# gamma = parameter.Uniform(0., 7.)('gamma')

# s+= gp_signals.FourierBasisGP(
#     spectrum=gp_priors.powerlaw(log10_A=log10_A, gamma = gamma),
#     modes = sig_unc.freqs,
#     # components = len(sig_unc.freqs),
#     Tspan=Tspan,
#     name="red_noise",
# )
log10_rho = parameter.Uniform(-9., -2., size=len(sig_unc.freqs))
s+= gp_signals.FourierBasisGP(
    spectrum=gp_priors.free_spectrum(log10_rho=log10_rho),
    components=len(sig_unc.freqs),
    modes = sig_unc.freqs,
    Tspan=Tspan,
    # name="red_noise",
)

pta = signal_base.PTA(
    [s(p) for p in psrs], signal_base.LogLikelihoodDenseCholesky
)

# %%
# pta.set_default_params(noise_dict)

# %%
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc

# %%
# ent_samp = sampler.setup_sampler(
#     pta,
#     # x0_user = np.hstack([p.sample() for p in pta.params]),
#     outdir="/data/taylor_group/Nima/PandorasBox/Trash/TrashCan",
#     resume=False,
#     empirical_distr=None,
#     groups=None,
#     human=None,
#     save_ext_dists=False,
#     loglkwargs={},
#     logpkwargs={},
# )
# set initial parameters drawn from prior
x0 = np.hstack([p.sample() for p in pta.params])
ndim = len(x0)
cov = np.diag(np.ones(ndim) * 0.01**2)
ent_samp = ptmcmc(ndim, pta.get_lnlikelihood, pta.get_lnprior, cov, 
                 outDir='/data/taylor_group/Nima/PandorasBox/Trash/GibbsTrashCan', resume=False)

# %%
ent_samp.sample(
    p0 = np.hstack([p.sample() for p in pta.params]),
    Niter = int(2e5),
    SCAMweight=30,
    AMweight=15,
    DEweight=50,
)

# %%
chain = np.loadtxt('/data/taylor_group/Nima/PandorasBox/Trash/GibbsTrashCan/chain_1.txt')
chain = chain[int(0.25 * chain.shape[0]):, :-4]
chain.shape

# %%
for fidx in range(6, 36):
    plt.hist(chain[:, fidx], **hist_settings)
    plt.hist(samples[:, fidx - 6], **hist_settings)
    plt.title(pta.param_names[fidx])
    plt.show()
